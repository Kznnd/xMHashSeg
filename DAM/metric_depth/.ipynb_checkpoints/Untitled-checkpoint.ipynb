# %%
import cv2
import torch

from depth_anything_v2.dpt import DepthAnythingV2
device = "cuda" if torch.cuda.is_available() else "cpu"
model_configs = {
    'vits': {'encoder': 'vits', 'features': 64, 'out_channels': [48, 96, 192, 384]},
    'vitb': {'encoder': 'vitb', 'features': 128, 'out_channels': [96, 192, 384, 768]},
    'vitl': {'encoder': 'vitl', 'features': 256, 'out_channels': [256, 512, 1024, 1024]}
}

encoder = 'vitl' # or 'vits', 'vitb'
dataset = 'vkitti' # 'hypersim' for indoor model, 'vkitti' for outdoor model
max_depth = 80 # 20 for indoor model, 80 for outdoor model

model = DepthAnythingV2(**{**model_configs[encoder], 'max_depth': max_depth})
model.load_state_dict(torch.load(f'checkpoints/depth_anything_v2_metric_{dataset}_{encoder}.pth', map_location=device))
model.eval()

raw_img = cv2.imread('rgb.png')
depth = model.infer_image(raw_img) # HxW depth map in meters in numpy
depth = (depth - depth.min()) / (depth.max() - depth.min()) * 255.0
depth = depth.astype(np.uint8)
depth = np.repeat(depth[..., np.newaxis], 3, axis=-1)
output_path = 'depth.png'
cv2.imwrite(output_path, depth)
# Out:
# xFormers not available
# xFormers not available
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 17
#      14 max_depth = 80 # 20 for indoor model, 80 for outdoor model
#      16 model = DepthAnythingV2(**{**model_configs[encoder], 'max_depth': max_depth})
# ---> 17 model.load_state_dict(torch.load(f'checkpoints/depth_anything_v2_metric_{dataset}_{encoder}.pth', map_location=device))
#      18 model.eval()
#      20 raw_img = cv2.imread('rgb.png')
#
# File D:\anaconda3\envs\tr\lib\site-packages\torch\serialization.py:809, in load(f, map_location, pickle_module, weights_only, **pickle_load_args)
#     807             except RuntimeError as e:
#     808                 raise pickle.UnpicklingError(UNSAFE_MESSAGE + str(e)) from None
# --> 809         return _load(opened_zipfile, map_location, pickle_module, **pickle_load_args)
#     810 if weights_only:
#     811     try:
#
# File D:\anaconda3\envs\tr\lib\site-packages\torch\serialization.py:1172, in _load(zip_file, map_location, pickle_module, pickle_file, **pickle_load_args)
#    1170 unpickler = UnpicklerWrapper(data_file, **pickle_load_args)
#    1171 unpickler.persistent_load = persistent_load
# -> 1172 result = unpickler.load()
#    1174 torch._utils._validate_loaded_sparse_tensors()
#    1176 return result
#
# File D:\anaconda3\envs\tr\lib\site-packages\torch\serialization.py:1141, in _load.<locals>.persistent_load(saved_id)
#    1139     typed_storage = loaded_storages[key]
#    1140 else:
# -> 1141     nbytes = numel * torch._utils._element_size(dtype)
#    1142     typed_storage = load_tensor(dtype, nbytes, key, _maybe_decode_ascii(location))
#    1144 return typed_storage
#
# AttributeError: module 'torch' has no attribute '_utils'
